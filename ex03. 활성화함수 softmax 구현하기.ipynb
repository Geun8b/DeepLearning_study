# %%
import numpy as np

# %%
def softmax(x) :
    e_x = np.exp(x - x.max())
    return e_x / e_x.sum()

# %%
x = np.array([1.0, 1.0, 2.0, 4.0, 21.0])
x
# Out:
# array([ 1.,  1.,  2.,  4., 21.])

# %%
y = softmax(x)
print(y)
print(y.sum())
# Out:
# [2.06115352e-09 2.06115352e-09 5.60279615e-09 4.13993751e-08
#  9.99999949e-01]
# 1.0
